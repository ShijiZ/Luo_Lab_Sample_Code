# %%
import numpy as np
import pandas as pd

basepath = '/Users/shijizhao/Documents/Lab_Luo/Data/data2-mmpbsa_raw/'

# %%
# Data frames for hypothesis 2:
# Phosphate group enables stronger binding
df_h2_Act_P1 = pd.DataFrame(columns=['DELTA TOTAL','Polyketide/Mimic','Pantetheine'])
df_h2_Act_P2 = pd.DataFrame(columns=['DELTA TOTAL','Polyketide/Mimic','Pantetheine'])
df_h2_Act_vdw = pd.DataFrame(columns=['VDWAALS','Polyketide/Mimic','Pantetheine'])

df_h2_Hed_P1 = pd.DataFrame(columns=['DELTA TOTAL','Polyketide/Mimic','Pantetheine'])
df_h2_Hed_P2 = pd.DataFrame(columns=['DELTA TOTAL','Polyketide/Mimic','Pantetheine'])
df_h2_Hed_vdw = pd.DataFrame(columns=['VDWAALS','Polyketide/Mimic','Pantetheine'])

# %%
### mtetp

mtetp_Act_P1 = pd.read_csv(basepath + 'ActKR-mtetp-joel-parameter1.csv')
mtetp_Act_P1['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Act_P1['Pantetheine'] = 'With P'

df_h2_Act_P1 = df_h2_Act_P1.append(mtetp_Act_P1,sort=False,ignore_index=True)

mtetp_Act_P2 = pd.read_csv(basepath + 'ActKR-mtetp-joel-parameter2.csv')
mtetp_Act_P2['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Act_P2['Pantetheine'] = 'With P'

df_h2_Act_P2 = df_h2_Act_P2.append(mtetp_Act_P2,sort=False,ignore_index=True)

mtetp_Act_vdw = pd.read_csv(basepath + 'ActKR-mtetp-joel-vdw.csv')
mtetp_Act_vdw['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Act_vdw['Pantetheine'] = 'With P'

df_h2_Act_vdw = df_h2_Act_vdw.append(mtetp_Act_vdw,sort=False,ignore_index=True)

mtetp_Hed_P1 = pd.read_csv(basepath + 'HedKR-mtetp-joel-parameter1.csv')
mtetp_Hed_P1['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Hed_P1['Pantetheine'] = 'With P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(mtetp_Hed_P1,sort=False,ignore_index=True)

mtetp_Hed_P2 = pd.read_csv(basepath + 'HedKR-mtetp-joel-parameter2.csv')
mtetp_Hed_P2['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Hed_P2['Pantetheine'] = 'With P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(mtetp_Hed_P2,sort=False,ignore_index=True)

mtetp_Hed_vdw = pd.read_csv(basepath + 'HedKR-mtetp-joel-vdw.csv')
mtetp_Hed_vdw['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetp_Hed_vdw['Pantetheine'] = 'With P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(mtetp_Hed_vdw,sort=False,ignore_index=True)

# %%
### tetp

tetp_Act_P1 = pd.read_csv(basepath + 'ActKR-tetp-joel-parameter1.csv')
tetp_Act_P1['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Act_P1['Pantetheine'] = 'With P'

df_h2_Act_P1 = df_h2_Act_P1.append(tetp_Act_P1,sort=False,ignore_index=True)

tetp_Act_P2 = pd.read_csv(basepath + 'ActKR-tetp-joel-parameter2.csv')
tetp_Act_P2['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Act_P2['Pantetheine'] = 'With P'

df_h2_Act_P2 = df_h2_Act_P2.append(tetp_Act_P2,sort=False,ignore_index=True)

tetp_Act_vdw = pd.read_csv(basepath + 'ActKR-tetp-joel-vdw.csv')
tetp_Act_vdw['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Act_vdw['Pantetheine'] = 'With P'

df_h2_Act_vdw = df_h2_Act_vdw.append(tetp_Act_vdw,sort=False,ignore_index=True)

tetp_Hed_P1 = pd.read_csv(basepath + 'HedKR-tetp-joel-parameter1.csv')
tetp_Hed_P1['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Hed_P1['Pantetheine'] = 'With P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(tetp_Hed_P1,sort=False,ignore_index=True)

tetp_Hed_P2 = pd.read_csv(basepath + 'HedKR-tetp-joel-parameter2.csv')
tetp_Hed_P2['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Hed_P2['Pantetheine'] = 'With P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(tetp_Hed_P2,sort=False,ignore_index=True)

tetp_Hed_vdw = pd.read_csv(basepath + 'HedKR-tetp-joel-vdw.csv')
tetp_Hed_vdw['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetp_Hed_vdw['Pantetheine'] = 'With P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(tetp_Hed_vdw,sort=False,ignore_index=True)

# %%
### mtetpnop

mtetpnop_Act_P1 = pd.read_csv(basepath + 'ActKR-mtetpnop-joel-parameter1.csv')
mtetpnop_Act_P1['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Act_P1['Pantetheine'] = 'Without P'

df_h2_Act_P1 = df_h2_Act_P1.append(mtetpnop_Act_P1,sort=False,ignore_index=True)

mtetpnop_Act_P2 = pd.read_csv(basepath + 'ActKR-mtetpnop-joel-parameter2.csv')
mtetpnop_Act_P2['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Act_P2['Pantetheine'] = 'Without P'

df_h2_Act_P2 = df_h2_Act_P2.append(mtetpnop_Act_P2,sort=False,ignore_index=True)

mtetpnop_Act_vdw = pd.read_csv(basepath + 'ActKR-mtetpnop-joel-vdw.csv')
mtetpnop_Act_vdw['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Act_vdw['Pantetheine'] = 'Without P'

df_h2_Act_vdw = df_h2_Act_vdw.append(mtetpnop_Act_vdw,sort=False,ignore_index=True)

mtetpnop_Hed_P1 = pd.read_csv(basepath + 'HedKR-mtetpnop-joel-parameter1.csv')
mtetpnop_Hed_P1['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Hed_P1['Pantetheine'] = 'Without P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(mtetpnop_Hed_P1,sort=False,ignore_index=True)

mtetpnop_Hed_P2 = pd.read_csv(basepath + 'HedKR-mtetpnop-joel-parameter2.csv')
mtetpnop_Hed_P2['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Hed_P2['Pantetheine'] = 'Without P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(mtetpnop_Hed_P2,sort=False,ignore_index=True)

mtetpnop_Hed_vdw = pd.read_csv(basepath + 'HedKR-mtetpnop-joel-vdw.csv')
mtetpnop_Hed_vdw['Polyketide/Mimic'] = 'Tetraketide/Mimic'
mtetpnop_Hed_vdw['Pantetheine'] = 'Without P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(mtetpnop_Hed_vdw,sort=False,ignore_index=True)

# %%
### tetpnop

tetpnop_Act_P1 = pd.read_csv(basepath + 'ActKR-tetpnop-joel-parameter1.csv')
tetpnop_Act_P1['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Act_P1['Pantetheine'] = 'Without P'

df_h2_Act_P1 = df_h2_Act_P1.append(tetpnop_Act_P1,sort=False,ignore_index=True)

tetpnop_Act_P2 = pd.read_csv(basepath + 'ActKR-tetpnop-joel-parameter2.csv')
tetpnop_Act_P2['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Act_P2['Pantetheine'] = 'Without P'

df_h2_Act_P2 = df_h2_Act_P2.append(tetpnop_Act_P2,sort=False,ignore_index=True)

tetpnop_Act_vdw = pd.read_csv(basepath + 'ActKR-tetpnop-joel-vdw.csv')
tetpnop_Act_vdw['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Act_vdw['Pantetheine'] = 'Without P'

df_h2_Act_vdw = df_h2_Act_vdw.append(tetpnop_Act_vdw,sort=False,ignore_index=True)

tetpnop_Hed_P1 = pd.read_csv(basepath + 'HedKR-tetpnop-joel-parameter1.csv')
tetpnop_Hed_P1['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Hed_P1['Pantetheine'] = 'Without P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(tetpnop_Hed_P1,sort=False,ignore_index=True)

tetpnop_Hed_P2 = pd.read_csv(basepath + 'HedKR-tetpnop-joel-parameter2.csv')
tetpnop_Hed_P2['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Hed_P2['Pantetheine'] = 'Without P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(tetpnop_Hed_P2,sort=False,ignore_index=True)

tetpnop_Hed_vdw = pd.read_csv(basepath + 'HedKR-tetpnop-joel-vdw.csv')
tetpnop_Hed_vdw['Polyketide/Mimic'] = 'Tetraketide/Natural'
tetpnop_Hed_vdw['Pantetheine'] = 'Without P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(tetpnop_Hed_vdw,sort=False,ignore_index=True)

# %%
### moctp

moctp_Act_P1 = pd.read_csv(basepath + 'ActKR-moctp-gabe-parameter1.csv')
moctp_Act_P1['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Act_P1['Pantetheine'] = 'With P'

df_h2_Act_P1 = df_h2_Act_P1.append(moctp_Act_P1,sort=False,ignore_index=True)

moctp_Act_P2 = pd.read_csv(basepath + 'ActKR-moctp-gabe-parameter2.csv')
moctp_Act_P2['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Act_P2['Pantetheine'] = 'With P'

df_h2_Act_P2 = df_h2_Act_P2.append(moctp_Act_P2,sort=False,ignore_index=True)

moctp_Act_vdw = pd.read_csv(basepath + 'ActKR-moctp-gabe-vdw.csv')
moctp_Act_vdw['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Act_vdw['Pantetheine'] = 'With P'

df_h2_Act_vdw = df_h2_Act_vdw.append(moctp_Act_vdw,sort=False,ignore_index=True)

moctp_Hed_P1 = pd.read_csv(basepath + 'HedKR-moctp-align-parameter1.csv')
moctp_Hed_P1['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Hed_P1['Pantetheine'] = 'With P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(moctp_Hed_P1,sort=False,ignore_index=True)

moctp_Hed_P2 = pd.read_csv(basepath + 'HedKR-moctp-align-parameter2.csv')
moctp_Hed_P2['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Hed_P2['Pantetheine'] = 'With P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(moctp_Hed_P2,sort=False,ignore_index=True)

moctp_Hed_vdw = pd.read_csv(basepath + 'HedKR-moctp-align-vdw.csv')
moctp_Hed_vdw['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctp_Hed_vdw['Pantetheine'] = 'With P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(moctp_Hed_vdw,sort=False,ignore_index=True)

# %%
### octp

octp_Act_P1 = pd.read_csv(basepath + 'ActKR-octp-gabe-parameter1.csv')
octp_Act_P1['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Act_P1['Pantetheine'] = 'With P'

df_h2_Act_P1 = df_h2_Act_P1.append(octp_Act_P1,sort=False,ignore_index=True)

octp_Act_P2 = pd.read_csv(basepath + 'ActKR-octp-gabe-parameter2.csv')
octp_Act_P2['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Act_P2['Pantetheine'] = 'With P'

df_h2_Act_P2 = df_h2_Act_P2.append(octp_Act_P2,sort=False,ignore_index=True)

octp_Act_vdw = pd.read_csv(basepath + 'ActKR-octp-gabe-vdw.csv')
octp_Act_vdw['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Act_vdw['Pantetheine'] = 'With P'

df_h2_Act_vdw = df_h2_Act_vdw.append(octp_Act_vdw,sort=False,ignore_index=True)

octp_Hed_P1 = pd.read_csv(basepath + 'HedKR-octp-align-parameter1.csv')
octp_Hed_P1['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Hed_P1['Pantetheine'] = 'With P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(octp_Hed_P1,sort=False,ignore_index=True)

octp_Hed_P2 = pd.read_csv(basepath + 'HedKR-octp-align-parameter2.csv')
octp_Hed_P2['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Hed_P2['Pantetheine'] = 'With P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(octp_Hed_P2,sort=False,ignore_index=True)

octp_Hed_vdw = pd.read_csv(basepath + 'HedKR-octp-align-vdw.csv')
octp_Hed_vdw['Polyketide/Mimic'] = 'Octaketide/Natural'
octp_Hed_vdw['Pantetheine'] = 'With P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(octp_Hed_vdw,sort=False,ignore_index=True)

# %%
### moctpnop

moctpnop_Act_P1 = pd.read_csv(basepath + 'ActKR-moctpnop-gabe-parameter1.csv')
moctpnop_Act_P1['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Act_P1['Pantetheine'] = 'Without P'

df_h2_Act_P1 = df_h2_Act_P1.append(moctpnop_Act_P1,sort=False,ignore_index=True)

moctpnop_Act_P2 = pd.read_csv(basepath + 'ActKR-moctpnop-gabe-parameter2.csv')
moctpnop_Act_P2['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Act_P2['Pantetheine'] = 'Without P'

df_h2_Act_P2 = df_h2_Act_P2.append(moctpnop_Act_P2,sort=False,ignore_index=True)

moctpnop_Act_vdw = pd.read_csv(basepath + 'ActKR-moctpnop-gabe-vdw.csv')
moctpnop_Act_vdw['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Act_vdw['Pantetheine'] = 'Without P'

df_h2_Act_vdw = df_h2_Act_vdw.append(moctpnop_Act_vdw,sort=False,ignore_index=True)

moctpnop_Hed_P1 = pd.read_csv(basepath + 'HedKR-moctpnop-align-parameter1.csv')
moctpnop_Hed_P1['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Hed_P1['Pantetheine'] = 'Without P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(moctpnop_Hed_P1,sort=False,ignore_index=True)

moctpnop_Hed_P2 = pd.read_csv(basepath + 'HedKR-moctpnop-align-parameter2.csv')
moctpnop_Hed_P2['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Hed_P2['Pantetheine'] = 'Without P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(moctpnop_Hed_P2,sort=False,ignore_index=True)

moctpnop_Hed_vdw = pd.read_csv(basepath + 'HedKR-moctpnop-align-vdw.csv')
moctpnop_Hed_vdw['Polyketide/Mimic'] = 'Octaketide/Mimic'
moctpnop_Hed_vdw['Pantetheine'] = 'Without P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(moctpnop_Hed_vdw,sort=False,ignore_index=True)

# %%
### octpnop

octpnop_Act_P1 = pd.read_csv(basepath + 'ActKR-octpnop-gabe-parameter1.csv')
octpnop_Act_P1['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Act_P1['Pantetheine'] = 'Without P'

df_h2_Act_P1 = df_h2_Act_P1.append(octpnop_Act_P1,sort=False,ignore_index=True)

octpnop_Act_P2 = pd.read_csv(basepath + 'ActKR-octpnop-gabe-parameter2.csv')
octpnop_Act_P2['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Act_P2['Pantetheine'] = 'Without P'

df_h2_Act_P2 = df_h2_Act_P2.append(octpnop_Act_P2,sort=False,ignore_index=True)

octpnop_Act_vdw = pd.read_csv(basepath + 'ActKR-octpnop-gabe-vdw.csv')
octpnop_Act_vdw['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Act_vdw['Pantetheine'] = 'Without P'

df_h2_Act_vdw = df_h2_Act_vdw.append(octpnop_Act_vdw,sort=False,ignore_index=True)

octpnop_Hed_P1 = pd.read_csv(basepath + 'HedKR-octpnop-align-parameter1.csv')
octpnop_Hed_P1['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Hed_P1['Pantetheine'] = 'Without P'

df_h2_Hed_P1 = df_h2_Hed_P1.append(octpnop_Hed_P1,sort=False,ignore_index=True)

octpnop_Hed_P2 = pd.read_csv(basepath + 'HedKR-octpnop-align-parameter2.csv')
octpnop_Hed_P2['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Hed_P2['Pantetheine'] = 'Without P'

df_h2_Hed_P2 = df_h2_Hed_P2.append(octpnop_Hed_P2,sort=False,ignore_index=True)

octpnop_Hed_vdw = pd.read_csv(basepath + 'HedKR-octpnop-align-vdw.csv')
octpnop_Hed_vdw['Polyketide/Mimic'] = 'Octaketide/Natural'
octpnop_Hed_vdw['Pantetheine'] = 'Without P'

df_h2_Hed_vdw = df_h2_Hed_vdw.append(octpnop_Hed_vdw,sort=False,ignore_index=True)

# %%
## P1 Check

print(df_h2_Act_P1['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Act_P1['Pantetheine'].value_counts())

print(df_h2_Hed_P1['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Hed_P1['Pantetheine'].value_counts())

## P2 Check

print(df_h2_Act_P2['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Act_P2['Pantetheine'].value_counts())

print(df_h2_Hed_P2['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Hed_P2['Pantetheine'].value_counts())

## vdw Check

print(df_h2_Act_vdw['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Act_vdw['Pantetheine'].value_counts())

print(df_h2_Hed_vdw['Polyketide/Mimic'].value_counts())
print()
print(df_h2_Hed_vdw['Pantetheine'].value_counts())

df_h2_Act_P1 = df_h2_Act_P1.rename(columns={"DELTA TOTAL":"Energy"})
df_h2_Act_P2 = df_h2_Act_P2.rename(columns={"DELTA TOTAL":"Energy"})
df_h2_Act_vdw = df_h2_Act_vdw.rename(columns={"VDWAALS":"Energy"})
df_h2_Hed_P1 = df_h2_Hed_P1.rename(columns={"DELTA TOTAL":"Energy"})
df_h2_Hed_P2 = df_h2_Hed_P2.rename(columns={"DELTA TOTAL":"Energy"})
df_h2_Hed_vdw = df_h2_Hed_vdw.rename(columns={"VDWAALS":"Energy"})

basepath2 = '/Users/shijizhao/Documents/Lab_Luo/Data/data4-mmpbsa-t-test/'

df_h2_Act_P1.to_csv(basepath2+'mmpbsa_h2_Act_P1.csv',index=False)
df_h2_Act_P2.to_csv(basepath2+'mmpbsa_h2_Act_P2.csv',index=False)
df_h2_Act_vdw.to_csv(basepath2+'mmpbsa_h2_Act_vdw.csv',index=False)
df_h2_Hed_P1.to_csv(basepath2+'mmpbsa_h2_Hed_P1.csv',index=False)
df_h2_Hed_P2.to_csv(basepath2+'mmpbsa_h2_Hed_P2.csv',index=False)
df_h2_Hed_vdw.to_csv(basepath2+'mmpbsa_h2_Hed_vdw.csv',index=False)
# Out:
# Tetraketide/Natural    400
# Tetraketide/Mimic      400
# Octaketide/Natural     400
# Octaketide/Mimic       400
# Name: Polyketide/Mimic, dtype: int64
#
# With P       800
# Without P    800
# Name: Pantetheine, dtype: int64
# Tetraketide/Natural    400
# Tetraketide/Mimic      400
# Octaketide/Natural     400
# Octaketide/Mimic       400
# Name: Polyketide/Mimic, dtype: int64
#
# With P       800
# Without P    800
# Name: Pantetheine, dtype: int64
# Tetraketide/Natural    400
# Tetraketide/Mimic      400
# Octaketide/Natural     400
# Octaketide/Mimic       400
# Name: Polyketide/Mimic, dtype: int64
#
# With P       800
# Without P    800
# Name: Pantetheine, dtype: int64
# Tetraketide/Natural    400
# Tetraketide/Mimic      400
# Octaketide/Natural     400
# Octaketide/Mimic       400
# Name: Polyketide/Mimic, dtype: int64
#
# With P       800
# Without P    800
# Name: Pantetheine, dtype: int64
# Tetraketide/Natural    400
# Tetraketide/Mimic      400
# ...
