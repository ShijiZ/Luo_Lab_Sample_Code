# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(columns=['Score','Binding_site','Ligand'])
basepath = '/Users/shijizhao/Documents/Lab_Luo/Data/data1-score-by-frame/'

# %%
ActKR_tetpp_front = pd.read_csv(basepath+'DM-ActKR-tetpp-front-score.csv')
ActKR_tetpp_front['Binding_site'] = 'Front_patch'
ActKR_tetpp_front['Ligand'] = 'tetpp'

df = df.append(ActKR_tetpp_front,sort=False,ignore_index=True)

ActKR_mtetpp_front = pd.read_csv(basepath+'DM-ActKR-mtetpp-front-score.csv')
ActKR_mtetpp_front['Binding_site'] = 'Front_patch'
ActKR_mtetpp_front['Ligand'] = 'mtetpp'

df = df.append(ActKR_mtetpp_front,sort=False,ignore_index=True)

ActKR_tetp_front = pd.read_csv(basepath+'DM-ActKR-tetp-front-score.csv')
ActKR_tetp_front['Binding_site'] = 'Front_patch'
ActKR_tetp_front['Ligand'] = 'tetp'

df = df.append(ActKR_tetp_front,sort=False,ignore_index=True)

ActKR_mtetp_front = pd.read_csv(basepath+'DM-ActKR-mtetp-front-score.csv')
ActKR_mtetp_front['Binding_site'] = 'Front_patch'
ActKR_mtetp_front['Ligand'] = 'mtetp'

df = df.append(ActKR_mtetp_front,sort=False,ignore_index=True)

ActKR_octpp_front = pd.read_csv(basepath+'DM-ActKR-octpp-front-score.csv')
ActKR_octpp_front['Binding_site'] = 'Front_patch'
ActKR_octpp_front['Ligand'] = 'octpp'

df = df.append(ActKR_octpp_front,sort=False,ignore_index=True)

ActKR_moctpp_front = pd.read_csv(basepath+'DM-ActKR-moctpp-front-score.csv')
ActKR_moctpp_front['Binding_site'] = 'Front_patch'
ActKR_moctpp_front['Ligand'] = 'moctpp'

df = df.append(ActKR_moctpp_front,sort=False,ignore_index=True)

ActKR_octp_front = pd.read_csv(basepath+'DM-ActKR-octp-front-score.csv')
ActKR_octp_front['Binding_site'] = 'Front_patch'
ActKR_octp_front['Ligand'] = 'octp'

df = df.append(ActKR_octp_front,sort=False,ignore_index=True)

ActKR_moctp_front = pd.read_csv(basepath+'DM-ActKR-moctp-front-score.csv')
ActKR_moctp_front['Binding_site'] = 'Front_patch'
ActKR_moctp_front['Ligand'] = 'moctp'

df = df.append(ActKR_moctp_front,sort=False,ignore_index=True)

ActKR_tetpp_back = pd.read_csv(basepath+'DM-ActKR-tetpp-back-score.csv')
ActKR_tetpp_back['Binding_site'] = 'Back_patch'
ActKR_tetpp_back['Ligand'] = 'tetpp'

df = df.append(ActKR_tetpp_back,sort=False,ignore_index=True)

ActKR_mtetpp_back = pd.read_csv(basepath+'DM-ActKR-mtetpp-back-score.csv')
ActKR_mtetpp_back['Binding_site'] = 'Back_patch'
ActKR_mtetpp_back['Ligand'] = 'mtetpp'

df = df.append(ActKR_mtetpp_back,sort=False,ignore_index=True)

ActKR_tetp_back = pd.read_csv(basepath+'DM-ActKR-tetp-back-score.csv')
ActKR_tetp_back['Binding_site'] = 'Back_patch'
ActKR_tetp_back['Ligand'] = 'tetp'

df = df.append(ActKR_tetp_back,sort=False,ignore_index=True)

ActKR_mtetp_back = pd.read_csv(basepath+'DM-ActKR-mtetp-back-score.csv')
ActKR_mtetp_back['Binding_site'] = 'Back_patch'
ActKR_mtetp_back['Ligand'] = 'mtetp'

df = df.append(ActKR_mtetp_back,sort=False,ignore_index=True)

ActKR_octpp_back = pd.read_csv(basepath+'DM-ActKR-octpp-back-score.csv')
ActKR_octpp_back['Binding_site'] = 'Back_patch'
ActKR_octpp_back['Ligand'] = 'octpp'

df = df.append(ActKR_octpp_back,sort=False,ignore_index=True)

ActKR_moctpp_back = pd.read_csv(basepath+'DM-ActKR-moctpp-back-score.csv')
ActKR_moctpp_back['Binding_site'] = 'Back_patch'
ActKR_moctpp_back['Ligand'] = 'moctpp'

df = df.append(ActKR_moctpp_back,sort=False,ignore_index=True)

ActKR_octp_back = pd.read_csv(basepath+'DM-ActKR-octp-back-score.csv')
ActKR_octp_back['Binding_site'] = 'Back_patch'
ActKR_octp_back['Ligand'] = 'octp'

df = df.append(ActKR_octp_back,sort=False,ignore_index=True)

ActKR_moctp_back = pd.read_csv(basepath+'DM-ActKR-moctp-back-score.csv')
ActKR_moctp_back['Binding_site'] = 'Back_patch'
ActKR_moctp_back['Ligand'] = 'moctp'

df = df.append(ActKR_moctp_back,sort=False,ignore_index=True)

print(df['Binding_site'].value_counts())
print()
print(df['Ligand'].value_counts())

df.to_csv('/Users/shijizhao/Documents/Lab_Luo/Data/data4-score-t-test/Score_by_frame_binding_position.csv',index=False)
# Out:
# Back_patch     2400
# Front_patch    2400
# Name: Binding_site, dtype: int64
#
# octpp     600
# mtetp     600
# tetpp     600
# tetp      600
# octp      600
# moctp     600
# mtetpp    600
# moctpp    600
# Name: Ligand, dtype: int64
