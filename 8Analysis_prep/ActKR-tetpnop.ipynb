# %%
import Traj_Analyzer as TA

# %%
basepath = '/Users/shijizhao/Documents/Lab_Luo/ActKR/Joel/tetpnop/'

# %%
rec_subpath = 'ActKR_1_tetpnop_md_joel%s/rms/md_ActKR_joel%s.rms'
lig_subpath = 'ActKR_1_tetpnop_md_joel%s/rms/md_tetpnop_joel%s.rms'
title_name = 'RMSD Plot of ActKR-tetpnop Simulation'
fig_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel RMSD'
rec_name = 'ActKR'
lig_name = 'tetpnop'
TA.rmsdPlot(basepath, rec_subpath, lig_subpath, title_name, fig_name, rec_name, lig_name)

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi.csv'
title_name = 'Individual Energy Plot of ActKR-tetpnop (Parameter Set 1)'
fig_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-parameter1'
y_label = '$\Delta$G (kcal/mol)'
TA.energyPlot(basepath, subpath, title_name, y_label, fig_name)

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi3.csv'
title_name = 'Individual Energy Plot of ActKR-tetpnop (Parameter Set 2)'
fig_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-parameter2'
y_label = '$\Delta$G (kcal/mol)'
TA.energyPlot(basepath, subpath, title_name, y_label, fig_name)

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi.csv'
title_name = 'Individual Van der Waals Energy Plot of ActKR-tetpnop'
fig_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-vdw'
y_label = '$\Delta$E${vdw}$ (kcal/mol)'
TA.energyPlot(basepath, subpath, title_name, y_label, fig_name)

# %%
sim_list = [1,2]
n_size = 20

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi.csv'
csv_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-parameter1.csv'
col = 'DELTA TOTAL'
text = "energy (parameter set 1)"
TA.energySample(basepath, subpath, csv_name, sim_list, col, text, n_size)
# Out:
# The cumulative averageenergy (parameter set 1)of sim 1 DELTA TOTAL   -51.314842
# Name: 150, dtype: float64
# The cumulative averageenergy (parameter set 1)of sim 2 DELTA TOTAL   -45.114304
# Name: 150, dtype: float64

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi3.csv'
csv_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-parameter2.csv'
col = 'DELTA TOTAL'
text = "energy (parameter set 2)"
TA.energySample(basepath, subpath, csv_name, sim_list, col, text, n_size)
# Out:
# The cumulative averageenergy (parameter set 2)of sim 1 DELTA TOTAL   -22.433583
# Name: 150, dtype: float64
# The cumulative averageenergy (parameter set 2)of sim 2 DELTA TOTAL   -19.212482
# Name: 150, dtype: float64

# %%
subpath = 'tetpnop_ActKR_MMPBSA_joel%s/ActKR_1_tetpnop_joel%s_energy_indi.csv'
csv_name = '/Users/shijizhao/Desktop/ActKR-tetpnop-joel-vdw.csv'
col = 'VDWAALS'
text = "Van der Waals energy"
TA.energySample(basepath, subpath, csv_name, sim_list, col, text, n_size)
# Out:
# The cumulative averageVan der Waals energyof sim 1 VDWAALS   -51.208994
# Name: 150, dtype: float64
# The cumulative averageVan der Waals energyof sim 2 VDWAALS   -46.644249
# Name: 150, dtype: float64
